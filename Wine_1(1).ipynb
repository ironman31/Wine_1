# %%
from sklearn.model_selection import train_test_split

import pandas as pd
df=pd.read_csv('../input/wine-test/train.csv')

df

# %%
len(df['variety'].unique())
# Out:
# 28

# %%
from sklearn.preprocessing import LabelEncoder

le_o=LabelEncoder()
l=le_o.fit_transform(df['variety'])
l
# Out:
# array([ 5, 17, 11,  1,  9,  3, 17, 27, 14, 17, 22,  5,  6,  8, 17,  0, 17,
#         5, 11, 21,  3, 11, 14, 11,  0,  0,  9,  5,  0,  5, 17, 24,  3, 21,
#         5, 14,  3,  0, 22, 24, 26, 17, 24, 21,  2, 15, 16, 18, 20, 24, 21,
#         4, 24,  5,  3, 14, 10,  5,  3, 11, 22, 15, 14, 21,  3, 27, 19, 27,
#         9, 17, 11,  3, 18,  0,  5, 10, 15,  5, 14, 14, 22,  9, 23, 12, 27,
#        22,  9,  1, 15, 11, 17, 15, 14,  3,  0,  3, 14,  3, 17,  5, 24, 14,
#        25,  5,  5, 17,  5, 22, 17,  3, 20,  6, 26, 14,  3, 23, 14, 24, 22,
#         3,  5,  5,  5, 19,  3,  1, 14,  4,  3, 10,  5, 13, 23, 23, 21, 27,
#        25, 14,  9, 13, 11, 23, 17, 14,  3,  3, 22, 20,  0, 14, 13, 19, 17,
#         3,  5, 14, 22,  3, 10, 23, 24,  0, 21, 11, 11,  3,  5, 11,  5,  0,
#         6, 24,  3, 11, 18, 11,  4, 22,  8, 14, 10, 24, 17, 25, 26, 17, 25,
#        14, 19, 22, 22, 14, 17,  6,  2, 15,  5, 14, 19, 20, 23,  2,  5,  0,
# ...

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# vectorizer = CountVectorizer()
# X = vectorizer.fit_transform(df['review_description'])
# # print(vectorizer.get_feature_names())
# # print(X.toarray())
# X3=X.toarray()

# # vectorizer2 = CountVectorizer(analyzer='word', ngram_range=(2, 2))
# # X2 = vectorizer2.fit_transform(df['review_description'])
# # print(vectorizer2.get_feature_names())

# # print(X2.toarray())

# %%
# c=X2.toarray()

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

# features = tfidf.fit_transform(df['review_description']).toarray()
# # labels = df['variety']
# # features.shape

# %%
/
# Out:
# ()

# %%
# import numpy as np

# np.save('array_1',features)

# %%
# # X_train, X_valid, y_train, y_valid = train_test_split(X3,l,
# #                                                       train_size=0.6, test_size=0.4,
# #                                                       random_state=0)

# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X3, l,
#                                                     stratify=l, 
#                                                     test_size=0.25)

# %%
# from sklearn.naive_bayes import MultinomialNB
# clf = MultinomialNB()
# clf.fit(X_train, y_train)

# %%
# # X_valid = tfidf.fit_transform(X_valid).toarray()
# from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import accuracy_score

# preds = clf.predict(X_valid)
# print(accuracy_score(y_valid, preds))

# print(accuracy_score(y_valid, preds, normalize=False))

# %%
# from sklearn.preprocessing import LabelEncoder

# le_o=LabelEncoder()
# l=le_o.fit_transform(df['variety'])
# l

# %%
# X_train, X_valid, y_train, y_valid = train_test_split(df['review_description'],l,
#                                                       train_size=0.6, test_size=0.4,
#                                                       random_state=0)

# %%
# X_train

# %%
# clf = MultinomialNB()
# clf.fit(features, labels)

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfTransformer
# from sklearn.naive_bayes import MultinomialNB

# count_vect = CountVectorizer()
# X_train_counts = count_vect.fit_transform(df['review_description'])
# tfidf_transformer = TfidfTransformer()
# X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
# clf = MultinomialNB().fit(X_train_tfidf, )

# %%
# vectorizer = TfidfVectorizer(stop_words='english')
# X = vectorizer.fit_transform(df['review_description'])
# pd.DataFrame(X)

# %%
cols_with_missing = [col for col in df.columns if df[col].isnull().sum() > 0.2*len(df)]
cols_with_missing
# Out:
# ['user_name', 'designation', 'region_2']

# %%
import pandas_profiling
print("Generating report with pandas profiling")
df.profile_report()
# Out:
# Generating report with pandas profiling
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
print(df['region_2'].unique())
print(len(df['region_2'].unique()))
# Out:
# [nan 'Columbia Valley' 'Sonoma' 'Willamette Valley' 'Napa-Sonoma'
#  'Central Coast' 'Napa' 'North Coast' 'California Other' 'Oregon Other'
#  'Sierra Foothills' 'Long Island' 'New York Other' 'Washington Other'
#  'Southern Oregon' 'Finger Lakes' 'Central Valley' 'South Coast']
# 18

# %%
df['review_description'][2]
# Out:
# 'Barolo Conca opens with inky dark concentration and soothing aromas of black fruit, spice, cola, plum, prune and dried lavender buds. The nose presents those ethereal and delicate aromas, but in the mouth, it delivers thicker flavors of chocolate and mocha. Drink after 2018.'

# %%
df['review_title'][2]
# Out:
# 'Renato Ratti 2007 Conca  (Barolo)'

# %%
df2=df.drop(['user_name','review_title', 'review_description'],axis=1)
df2
# Out:
#        country            designation  points  price          province  \
# 0    Australia  Peace Family Vineyard      83   10.0   Australia Other
# 1           US                    NaN      89   15.0        Washington
# 2        Italy                  Conca      94   80.0          Piedmont
# 3       France               L'Abbaye      87   22.0  Southwest France
# 4       France       Le Cèdre Vintage      88   33.0      France Other
# ..         ...                    ...     ...    ...               ...
# 995         US        Founder's Blend      91   30.0        Washington
# 996  Australia                    NaN      87   20.0          Victoria
# 997         US              Benchmark      91   95.0        California
# 998         US                    NaN      86   27.0            Oregon
# 999     France          Barrel sample      92    NaN          Bordeaux
#
#                     region_1         region_2                   winery  \
# ...

# %%
df2
# Out:
#        country            designation  points  price          province  \
# 0    Australia  Peace Family Vineyard      83   10.0   Australia Other
# 1           US                    NaN      89   15.0        Washington
# 2        Italy                  Conca      94   80.0          Piedmont
# 3       France               L'Abbaye      87   22.0  Southwest France
# 4       France       Le Cèdre Vintage      88   33.0      France Other
# ..         ...                    ...     ...    ...               ...
# 995         US        Founder's Blend      91   30.0        Washington
# 996  Australia                    NaN      87   20.0          Victoria
# 997         US              Benchmark      91   95.0        California
# 998         US                    NaN      86   27.0            Oregon
# 999     France          Barrel sample      92    NaN          Bordeaux
#
#                     region_1         region_2                   winery  \
# ...

# %%
df2=df2.fillna(0)
df2 = df2.applymap(str)

df2
# Out:
#        country            designation points price          province  \
# 0    Australia  Peace Family Vineyard     83  10.0   Australia Other
# 1           US                      0     89  15.0        Washington
# 2        Italy                  Conca     94  80.0          Piedmont
# 3       France               L'Abbaye     87  22.0  Southwest France
# 4       France       Le Cèdre Vintage     88  33.0      France Other
# ..         ...                    ...    ...   ...               ...
# 995         US        Founder's Blend     91  30.0        Washington
# 996  Australia                      0     87  20.0          Victoria
# 997         US              Benchmark     91  95.0        California
# 998         US                      0     86  27.0            Oregon
# 999     France          Barrel sample     92   0.0          Bordeaux
#
#                     region_1         region_2                   winery  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for i in df2.columns:
    print(df2[i])
    if isinstance(df2[i][1],str):
        print(i)
# #         df[df.columns[i]]=le_o.fit_transform(df[df.columns[i]])
# #         df[df.columns[i]]=df[df.columns[i]].apply(str)
#         df2[df2[i]]=df2[df2[i]].apply(str)

        le_o=LabelEncoder()
        df2[i]=le_o.fit_transform(df2[i])
# Out:
# 0      Australia
# 1             US
# 2          Italy
# 3         France
# 4         France
#          ...
# 995           US
# 996    Australia
# 997           US
# 998           US
# 999       France
# Name: country, Length: 1000, dtype: object
# country
# 0      Peace Family Vineyard
# 1                          0
# 2                      Conca
# 3                   L'Abbaye
# 4           Le Cèdre Vintage
#                ...
# 995          Founder's Blend
# 996                        0
# 997                Benchmark
# 998                        0
# 999            Barrel sample
# Name: designation, Length: 1000, dtype: object
# designation
# 0      83
# 1      89
# 2      94
# 3      87
# 4      88
#        ..
# 995    91
# 996    87
# 997    91
# 998    86
# 999    92
# Name: points, Length: 1000, dtype: object
# points
# 0      10.0
# 1      15.0
# 2      80.0
# 3      22.0
# 4      33.0
#        ...
# 995    30.0
# 996    20.0
# 997    95.0
# 998    27.0
# 999     0.0
# ...

# %%
df2
# Out:
#      country  designation  points  price  province  region_1  region_2  \
# 0          2          439       3      1         6       196         0
# 1         20            0       9     17        96        60         4
# 2         12          113      14     88        63        18         0
# 3          8          292       7     29        80        22         0
# 4          8          320       8     43        33       224         0
# ..       ...          ...     ...    ...       ...       ...       ...
# 995       20          219      11     38        96       236         4
# 996        2            0       7     26        91        97         0
# 997       20           32      11     96        17       137         7
# 998       20            0       6     35        59       197        15
# 999        8           25      12      0        10       112         0
#
#      winery  variety
# 0        31        5
# 1       633       17
# 2       699       11
# 3       322        1
# ...

# %%
type(df['price'][1])
# Out:
# numpy.float64

# %%
target=df2['variety']
data=df2[df2.columns[0:-1]]
data
# Out:
#      country  designation  points  price  province  region_1  region_2  winery
# 0          2          439       3      1         6       196         0      31
# 1         20            0       9     17        96        60         4     633
# 2         12          113      14     88        63        18         0     699
# 3          8          292       7     29        80        22         0     322
# 4          8          320       8     43        33       224         0     233
# ..       ...          ...     ...    ...       ...       ...       ...     ...
# 995       20          219      11     38        96       236         4     115
# 996        2            0       7     26        91        97         0     582
# 997       20           32      11     96        17       137         7     881
# 998       20            0       6     35        59       197        15     242
# 999        8           25      12      0        10       112         0     212
#
# [1000 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(data, target,
                                                      train_size=0.8, test_size=0.2,
                                                      random_state=0)

# %%
X_train
# Out:
#      country  designation  points  price  province  region_1  region_2  winery
# 687       12          616       7     61        79        84         0       8
# 500       20          289      12     66        17       171        13     569
# 332        6            2       5     94        67         0         0     741
# 979        8            0       5     35        14        47         0     303
# 817       20          480       8     38        96        60         4     460
# ..       ...          ...     ...    ...       ...       ...       ...     ...
# 835       20          297      10     65        59        75        17     823
# 192       12            0       8     36        90       216         0     775
# 629        8          515       3     17        70        70         0      10
# 559       20            0      13     32        17       183         2      20
# 684       12          323       6      0        90       215         0     133
#
# [800 rows x 8 columns]

# %%
# from sklearn.ensemble import RandomForestRegressor


# # function for comparing different approaches
# def score_dataset(X_train, X_valid, y_train, y_valid):
#     model = RandomForestRegressor(n_estimators=100, random_state=0)
#     model.fit(X_train, y_train)
#     preds = model.predict(X_valid)
    
#     print(mean_absolute_error(y_valid, preds))
    
#     return preds

# %%
# pr=score_dataset(X_train, X_valid, y_train, y_valid)

# %%
# import numpy as np

# pr=np.array(pr)

# %%
# import numpy as np
# y_valid=np.array(y_valid)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
preds = model.predict(X_valid)
# c=model.score([y_valid], [preds])
# print(c)

# %%
preds
# Out:
# array([11.37148156, 13.74943156, 14.97307456, 12.45962922, 15.39071283,
#        11.10161148,  8.5630194 , 13.81676155,  9.89741148, 12.7005478 ,
#        11.49020069,  9.64589233, 11.90460487, 11.40531173, 14.04283301,
#        10.31750555, 15.53516546, 13.09373954,  8.80409572,  9.85835906,
#        13.28356177, 10.43741926, 14.21989074, 13.26586427, 13.94899179,
#        16.55913311, 14.8479884 , 14.32848937, 13.48052039, 15.08563598,
#        15.98646322, 12.59083181,  8.15313414, 11.33623342,  9.79159622,
#        11.85725309, 12.07081016, 10.48199728, 14.6069269 , 12.2466936 ,
#        10.67083506, 11.46683223, 10.93760235, 20.62505106, 15.08741763,
#        14.47246554, 13.96802648, 17.37255151, 13.39038258, 10.6776199 ,
#        16.30190009, 14.15640112, 11.36921326, 14.01942431, 13.62526779,
#        13.92536543, 10.73814082, 12.36759881, 12.57006608, 17.26656952,
#        14.48440665, 12.21345812, 11.9948499 ,  8.25228602, 15.43031167,
# ...

# %%
y_valid
# Out:
# 993    27
# 859    17
# 298    17
# 553    11
# 672     3
#        ..
# 679    19
# 722     3
# 215     3
# 653     5
# 150    13
# Name: variety, Length: 200, dtype: int64

# %%
from sklearn import tree
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score


model=tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
preds = model.predict(X_valid)
print(accuracy_score(y_valid, preds))

print(accuracy_score(y_valid, preds, normalize=False))
# Out:
# 0.36
# 72

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=2)
neigh.fit(X_train, y_train)
preds = neigh.predict(X_valid)
print(accuracy_score(y_valid, preds))

print(accuracy_score(y_valid, preds, normalize=False))
# Out:
# 0.19
# 38

# %%
from sklearn.neural_network import MLPClassifier

neigh = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(1000, 300), random_state=1)
neigh.fit(X_train, y_train)
preds = neigh.predict(X_valid)
print(accuracy_score(y_valid, preds))

print(accuracy_score(y_valid, preds, normalize=False))
# Out:
# 0.11
# 22

# %%
from  sklearn.preprocessing  import StandardScaler
slc= StandardScaler()
X = slc.fit_transform(data)

# Spliting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, target, test_size = 0.2, random_state = 0)
X_train[1]
# Out:
# array([ 0.89647806,  0.26254948,  1.08900027,  1.1724371 , -0.79548473,
#         0.89251814,  1.87776393,  0.45190591])

# %%
X_train[3]
# Out:
# array([-1.07092075, -1.09737166, -1.12698865, -0.06891507, -0.89289103,
#        -0.69545571, -0.66557125, -0.57177686])

# %%
data
# Out:
#      country  designation  points  price  province  region_1  region_2  winery
# 0          2          439       3      1         6       196         0      31
# 1         20            0       9     17        96        60         4     633
# 2         12          113      14     88        63        18         0     699
# 3          8          292       7     29        80        22         0     322
# 4          8          320       8     43        33       224         0     233
# ..       ...          ...     ...    ...       ...       ...       ...     ...
# 995       20          219      11     38        96       236         4     115
# 996        2            0       7     26        91        97         0     582
# 997       20           32      11     96        17       137         7     881
# 998       20            0       6     35        59       197        15     242
# 999        8           25      12      0        10       112         0     212
#
# [1000 rows x 8 columns]

# %%
num_folds = 10
seed = 0
scoring = 'accuracy'

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# Spot-Check Algorithms (Classification)
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# Spot-Check Ensemble Models (Classification)
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, AdaBoostClassifier
# from xgboost.sklearn import XGBClassifier

models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('NB', GaussianNB()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
# models.append(('SVM', SVC()))

models.append(('AB', AdaBoostClassifier()))
models.append(('GBM', GradientBoostingClassifier()))
models.append(('ET', ExtraTreesClassifier()))
models.append(('RF', RandomForestClassifier()))
# models.append(('XGB',XGBClassifier()))

# evaluate each model in turn
results = {}
accuracy = {}
for name, model in models:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results[name] = (cv_results.mean(), cv_results.std())
    model.fit(X_train, y_train)
    _ = model.predict(X_test)
    accuracy[name] = accuracy_score(y_test, _)

# %%
accuracy
# Out:
# {'LR': 0.25,
#  'LDA': 0.265,
#  'NB': 0.24,
#  'KNN': 0.275,
#  'CART': 0.375,
#  'AB': 0.2,
#  'GBM': 0.41,
#  'ET': 0.435,
#  'RF': 0.4}

# %%
results
# Out:
# {'LR': (0.24250000000000002, 0.043732139211339754),
#  'LDA': (0.22875, 0.033564303955243874),
#  'NB': (0.20999999999999996, 0.043229041164476456),
#  'KNN': (0.25375, 0.023750000000000004),
#  'CART': (0.38375, 0.0447388254204332),
#  'AB': (0.16625, 0.02625),
#  'GBM': (0.42750000000000005, 0.04736823830374104),
#  'ET': (0.41125, 0.0472526454285895),
#  'RF': (0.42125, 0.027978786606999234)}

# %%
# Finalizing the model and comparing the test, predict results
import seaborn as sns

model = SVC(random_state=seed)

model.fit(X_train, y_train) 
y_predict = model.predict(X_test)

print(classification_report(y_test, y_predict))

cm= confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58        12
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         3
#            3       0.43      0.52      0.47        23
#            4       0.00      0.00      0.00         1
#            5       0.18      0.25      0.21        24
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00         3
#            9       0.43      0.43      0.43         7
#           10       0.00      0.00      0.00         6
#           11       0.36      0.71      0.48         7
#           12       0.00      0.00      0.00         2
#           13       0.00      0.00      0.00         1
#           14       0.40      0.66      0.50        32
#           15       0.00      0.00      0.00         1
#           16       1.00      0.40      0.57         5
# ...

# %%
print(accuracy_score(y_test, y_predict))

print(accuracy_score(y_test, y_predict, normalize=False))
# Out:
# 0.33
# 66

# %%
import xgboost as xgb
xgb_model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=2000, random_state=420, eval_metric=["auc", "error", "error@0.6"])

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_valid)

accuracy_score(y_valid, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-7d727cf159eb> in <module>
#       4 xgb_model.fit(X_train, y_train)
#       5
# ----> 6 y_pred = xgb_model.predict(X_valid)
#       7
#       8 accuracy_score(y_valid, y_pred)
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features, base_margin)
#     885             output_margin=output_margin,
#     886             ntree_limit=ntree_limit,
# --> 887             validate_features=validate_features)
#     888         if output_margin:
#     889             # If output_margin is active, simply return the scores
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training)
#    1441
# ...
